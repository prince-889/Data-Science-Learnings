# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ans1.

# %% [markdown]
# Matplotlib is a powerful plotting library in Python used for creating static, animated, and interactive visualizations.
#
# 1.Line Graph
# 2.Bar Chart
# 3.Histograms
# 4.Scatter Plot
# 5.Pie Chart

# %% [markdown]
# Ans2.

# %% [markdown]
# A scatter plot is a diagram where each value in the data set is represented by a dot.

# %%
np.random.seed(3)
x = 3+ np.random.normal(0,2,50)
y = 3+ np.random.normal(0,2,len(x))
plt.scatter(x,y)
plt.xlabel('X1')
plt.ylabel('Y1')
plt.title('Scatter Plot X1 vs Y1')
# Out:
# Text(0.5, 1.0, 'Scatter Plot X1 vs Y1')

# %% [markdown]
# Ans3.

# %% [markdown]
# With subplots(), users can easily create multiple plots in a single figure, making comparing and analyzing different datasets or variables easier.

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

fig, axes = plt.subplots(2,2)
axes[0,0].plot(x,y1)
axes[0,1].plot(x,y2)
axes[1,0].plot(x,y3)
axes[1,1].plot(x,y4)

plt.tight_layout()
plt.show()

# %% [markdown]
# Ans4.

# %% [markdown]
# Bar plots are a type of data visualization used to represent data in the form of rectangular bars.The height of each bar represents the value of a data point, and the width of each bar represents the category of the data.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit,)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Ans5.

# %% [markdown]
# Matplotlib's boxplot mainly provides a graphical summary of a data set with features such as minimum, first quartile, median, third quartile, and maximum.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x243edbf5e50>,
#   <matplotlib.lines.Line2D at 0x243edbf71a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x243edbf7440>,
#   <matplotlib.lines.Line2D at 0x243edbf76e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x243eaff7ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x243edbf78c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x243edbf7b30>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x243edc7dac0>,
#   <matplotlib.lines.Line2D at 0x243edc7ddc0>],
#  'caps': [<matplotlib.lines.Line2D at 0x243edc7df70>,
#   <matplotlib.lines.Line2D at 0x243edc7e270>],
#  'boxes': [<matplotlib.lines.Line2D at 0x243edc51a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x243edc7e540>],
#  'fliers': [<matplotlib.lines.Line2D at 0x243edc7e780>],
#  'means': []}
